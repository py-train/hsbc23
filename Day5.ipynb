# %%
import numpy as np
import pandas as pd

# %%
gapminder = pd.read_csv('data/gapminder_tidy.csv')
gapminder
# Out:
#            Country  Year  fertility    life  population  child_mortality  \
# 0      Afghanistan  1964      7.671  33.639  10474903.0            339.7
# 1      Afghanistan  1965      7.671  34.152  10697983.0            334.1
# 2      Afghanistan  1966      7.671  34.662  10927724.0            328.7
# 3      Afghanistan  1967      7.671  35.170  11163656.0            323.3
# 4      Afghanistan  1968      7.671  35.674  11411022.0            318.1
# ...            ...   ...        ...     ...         ...              ...
# 10106        Åland  2002        NaN  81.800     26257.0              NaN
# 10107        Åland  2003        NaN  80.630     26347.0              NaN
# 10108        Åland  2004        NaN  79.880     26530.0              NaN
# 10109        Åland  2005        NaN  80.000     26766.0              NaN
# 10110        Åland  2006        NaN  80.100     26923.0              NaN
#
#           gdp                 region
# 0      1182.0             South Asia
# ...

# %%
gapminder.tail(20)
# Out:
#         Country  Year  fertility    life  population  child_mortality     gdp  \
# 10091  Zimbabwe  2004      3.987  43.244  12597877.0             94.1  1794.0
# 10092  Zimbabwe  2005      3.969  43.958  12570686.0             96.2  1689.0
# 10093  Zimbabwe  2006      3.941  45.157  12529655.0             97.9  1629.0
# 10094  Zimbabwe  2007      3.903  46.827  12481245.0             98.7  1568.0
# 10095  Zimbabwe  2008      3.853  48.890  12451543.0             98.3  1286.0
# 10096  Zimbabwe  2009      3.792  51.234  12473992.0             97.3  1352.0
# 10097  Zimbabwe  2010      3.721  53.684  12571454.0             95.1  1484.0
# 10098  Zimbabwe  2011      3.643  56.040  12754378.0             92.0  1626.0
# 10099  Zimbabwe  2012      3.564  58.142  13013678.0             86.7  1750.0
# 10100  Zimbabwe  2013      3.486  59.871  13327925.0             83.3  1773.0
# 10101     Åland  1997        NaN  78.900         NaN              NaN     NaN
# ...

# %%
gapminder[gapminder.Country == 'Åland']
# Out:
#       Country  Year  fertility   life  population  child_mortality  gdp  \
# 10101   Åland  1997        NaN  78.90         NaN              NaN  NaN
# 10102   Åland  1998        NaN  81.00         NaN              NaN  NaN
# 10103   Åland  1999        NaN  78.25         NaN              NaN  NaN
# 10104   Åland  2000        NaN  80.00     25776.0              NaN  NaN
# 10105   Åland  2001        NaN  80.83     26008.0              NaN  NaN
# 10106   Åland  2002        NaN  81.80     26257.0              NaN  NaN
# 10107   Åland  2003        NaN  80.63     26347.0              NaN  NaN
# 10108   Åland  2004        NaN  79.88     26530.0              NaN  NaN
# 10109   Åland  2005        NaN  80.00     26766.0              NaN  NaN
# 10110   Åland  2006        NaN  80.10     26923.0              NaN  NaN
#
#                       region
# 10101  Europe & Central Asia
# 10102  Europe & Central Asia
# 10103  Europe & Central Asia
# 10104  Europe & Central Asia
# ...

# %%
# 1. Average life expectancy in India during the 1980's
56.89

# 2. What are the regions mentioned in this data?

# 3. Average life expectancy in India during the 2000's (temporal)
63+

# 4. ... South Asia(spatial)

# 5. ... Pakistan(spatial)

# %%
g = gapminder

# %%
# All metrics for all years for the South Asia region
g[g.region == 'South Asia'].mean()
# Out:
# Year               1.988500e+03
# fertility          5.004162e+00
# life               5.713771e+01
# population         1.406782e+08
# child_mortality    1.377672e+02
# gdp                2.552650e+03
# dtype: float64

# %%
g.groupby('region').mean()
# Out:
#                                    Year  fertility       life    population  \
# region
# America                     1988.500000   3.486061  68.722251  1.774572e+07
# East Asia & Pacific         1988.510931   3.725836  66.108632  5.468619e+07
# Europe & Central Asia       1988.550781   2.214177  71.931303  1.600358e+07
# Middle East & North Africa  1988.500000   4.970019  65.194301  1.171303e+07
# South Asia                  1988.500000   5.004162  57.137710  1.406782e+08
# Sub-Saharan Africa          1988.500000   5.956105  51.664426  1.050998e+07
#
#                             child_mortality           gdp
# region
# America                           50.513292  11599.921875
# East Asia & Pacific               59.337826  13336.156923
# Europe & Central Asia             30.180168  18442.045417
# Middle East & North Africa        69.884533  27510.731579
# South Asia                       137.767150   2552.650000
# Sub-Saharan Africa               158.917473   3152.428511

# %%
mean_pop_region = g.groupby('region')['population'].mean()
mean_pop_region
# Out:
# region
# America                       1.774572e+07
# East Asia & Pacific           5.468619e+07
# Europe & Central Asia         1.600358e+07
# Middle East & North Africa    1.171303e+07
# South Asia                    1.406782e+08
# Sub-Saharan Africa            1.050998e+07
# Name: population, dtype: float64

# %%
type(mean_pop_region)
# Out:
# pandas.core.series.Series

# %%
mean_pop_region.index
# Out:
# Index(['America', 'East Asia & Pacific', 'Europe & Central Asia',
#        'Middle East & North Africa', 'South Asia', 'Sub-Saharan Africa'],
#       dtype='object', name='region')

# %%
g.index
# Out:
# RangeIndex(start=0, stop=10111, step=1)

# %%
g.columns
# Out:
# Index(['Country', 'Year', 'fertility', 'life', 'population', 'child_mortality',
#        'gdp', 'region'],
#       dtype='object')

# %%
g.groupby('region').count()
# Out:
#                             Country  Year  fertility  life  population  \
# region
# America                        2000  2000       2000  2000        2000
# East Asia & Pacific            1601  1601       1600  1601        1601
# Europe & Central Asia          2560  2560       2550  2560        2557
# Middle East & North Africa     1050  1050       1050  1050        1050
# South Asia                      400   400        400   400         400
# Sub-Saharan Africa             2500  2500       2500  2500        2500
#
#                             child_mortality   gdp
# region
# America                                1704  1600
# East Asia & Pacific                    1320  1300
# Europe & Central Asia                  2384  2400
# Middle East & North Africa              984   950
# South Asia                              400   400
# Sub-Saharan Africa                     2418  2350

# %%
g.groupby('region').size()
# Out:
# region
# America                       2000
# East Asia & Pacific           1601
# Europe & Central Asia         2560
# Middle East & North Africa    1050
# South Asia                     400
# Sub-Saharan Africa            2500
# dtype: int64

# %%
# How many years was the lexp in SA countries greater than 60
g[(g.region == 'South Asia') & (g.life > 60)].groupby('Country').size()
# Out:
# Country
# Afghanistan     3
# Bangladesh     24
# Bhutan         14
# India          19
# Maldives       24
# Nepal          17
# Pakistan       27
# Sri Lanka      50
# dtype: int64

# %%
g[(g.region == 'South Asia') & (g.life > 60)]['Country'].value_counts()
# Out:
# Sri Lanka      50
# Pakistan       27
# Maldives       24
# Bangladesh     24
# India          19
# Nepal          17
# Bhutan         14
# Afghanistan     3
# Name: Country, dtype: int64

# %%
g[(g.region == 'South Asia') & (g.life > 60)]

# %%
g[(g.region == 'South Asia') & (g.life > 60)].groupby('Country').size().\
sort_values(ascending=False)
# Out:
# Country
# Sri Lanka      50
# Pakistan       27
# Bangladesh     24
# Maldives       24
# India          19
# Nepal          17
# Bhutan         14
# Afghanistan     3
# dtype: int64

# %%
g.Country.value_counts(True)

# %%
# Use of keyword arguments: to be preferred over positional args

g[(g.region == 'South Asia') & (g.life > 60)]['Country']\
.value_counts(normalize=True, ascending=True) * 100
# Out:
# Afghanistan     1.685393
# Bhutan          7.865169
# Nepal           9.550562
# India          10.674157
# Maldives       13.483146
# Bangladesh     13.483146
# Pakistan       15.168539
# Sri Lanka      28.089888
# Name: Country, dtype: float64

# %%
# How many countries per region?
South Asia          6
Sub-Saharan Africa  12

# %%
g.groupby('region').size()
# Out:
# region
# America                       2000
# East Asia & Pacific           1601
# Europe & Central Asia         2560
# Middle East & North Africa    1050
# South Asia                     400
# Sub-Saharan Africa            2500
# dtype: int64

# %%
g.groupby(['region', 'Country']).size()
# Out:
# region              Country
# America             Antigua and Barbuda    50
#                     Argentina              50
#                     Aruba                  50
#                     Bahamas                50
#                     Barbados               50
#                                            ..
# Sub-Saharan Africa  Tanzania               50
#                     Togo                   50
#                     Uganda                 50
#                     Zambia                 50
#                     Zimbabwe               50
# Length: 204, dtype: int64

# %%
g.groupby(['region', 'Country']).size().index
# Out:
# MultiIndex([(           'America', 'Antigua and Barbuda'),
#             (           'America',           'Argentina'),
#             (           'America',               'Aruba'),
#             (           'America',             'Bahamas'),
#             (           'America',            'Barbados'),
#             (           'America',              'Belize'),
#             (           'America',             'Bolivia'),
#             (           'America',              'Brazil'),
#             (           'America',              'Canada'),
#             (           'America',               'Chile'),
#             ...
#             ('Sub-Saharan Africa',             'Somalia'),
#             ('Sub-Saharan Africa',        'South Africa'),
#             ('Sub-Saharan Africa',         'South Sudan'),
#             ('Sub-Saharan Africa',               'Sudan'),
#             ('Sub-Saharan Africa',           'Swaziland'),
#             ('Sub-Saharan Africa',            'Tanzania'),
# ...

# %%
g.groupby(['Country', 'Year'])['fertility'].mean()
# Out:
# Country      Year
# Afghanistan  1964    7.671
#              1965    7.671
#              1966    7.671
#              1967    7.671
#              1968    7.671
#                      ...
# Åland        2002      NaN
#              2003      NaN
#              2004      NaN
#              2005      NaN
#              2006      NaN
# Name: fertility, Length: 10111, dtype: float64

# %%
g.groupby(['Country', 'Year'])['fertility'].max()
# Out:
# Country      Year
# Afghanistan  1964    7.671
#              1965    7.671
#              1966    7.671
#              1967    7.671
#              1968    7.671
#                      ...
# Åland        2002      NaN
#              2003      NaN
#              2004      NaN
#              2005      NaN
#              2006      NaN
# Name: fertility, Length: 10111, dtype: float64

# %%
g[(g.Country=='Afghanistan') & (g.Year==1964)]['fertility'].max()
# Out:
# 7.671

# %%
g.groupby('Country')['fertility'].max()
# Out:
# Country
# Afghanistan            7.869
# Albania                5.711
# Algeria                7.658
# Angola                 7.430
# Antigua and Barbuda    4.250
#                        ...
# Western Sahara         6.620
# Yemen, Rep.            9.223
# Zambia                 7.447
# Zimbabwe               7.420
# Åland                    NaN
# Name: fertility, Length: 204, dtype: float64

# %%
g[(g.Country=='Afghanistan')]['fertility'].max()
# Out:
# 7.869

# %%
g.groupby(['region', 'Country'])['life'].mean()
# Out:
# region              Country
# America             Antigua and Barbuda    70.63692
#                     Argentina              71.09126
#                     Aruba                  72.48278
#                     Bahamas                70.11278
#                     Barbados               70.12256
#                                              ...
# Sub-Saharan Africa  Tanzania               50.86756
#                     Togo                   52.33336
#                     Uganda                 49.81892
#                     Zambia                 47.73318
#                     Zimbabwe               53.96624
# Name: life, Length: 204, dtype: float64

# %%
g.groupby(['Country', 'Year'])['fertility'].max().unstack(level=0).plot()

# %%
g.groupby(['region', 'Year'])['fertility'].max().unstack(level=0)\
.plot(figsize=(10,5))

# %%
# Fertility trends for all countries of the South-Asia region
fcsa = g[g.region == 'South Asia'].groupby(['Country', 'Year'])['fertility']\
        .mean()
fcsa
# Out:
# Country      Year
# Afghanistan  1964    7.671
#              1965    7.671
#              1966    7.671
#              1967    7.671
#              1968    7.671
#                      ...
# Sri Lanka    2009    2.335
#              2010    2.343
#              2011    2.347
#              2012    2.346
#              2013    2.339
# Name: fertility, Length: 400, dtype: float64

# %%
fcsa.index.levels[0]
# Out:
# Index(['Afghanistan', 'Bangladesh', 'Bhutan', 'India', 'Maldives', 'Nepal',
#        'Pakistan', 'Sri Lanka'],
#       dtype='object', name='Country')

# %%
fcsa.unstack(level=0).plot(figsize=(12,5))

# %%
fcsa.head(100).tail(50)
# Out:
# Country     Year
# Bangladesh  1964    6.853
#             1965    6.878
#             1966    6.901
#             1967    6.920
#             1968    6.935
#             1969    6.945
#             1970    6.947
#             1971    6.942
#             1972    6.928
#             1973    6.904
#             1974    6.869
#             1975    6.821
#             1976    6.758
#             1977    6.680
#             1978    6.587
#             1979    6.480
#             1980    6.356
#             1981    6.216
#             1982    6.060
#             1983    5.890
#             1984    5.710
#             1985    5.522
#             1986    5.327
#             1987    5.130
#             1988    4.932
#             1989    4.738
#             1990    4.550
#             1991    4.370
#             1992    4.197
#             1993    4.033
#             1994    3.878
#             1995    3.732
#             1996    3.596
#             1997    3.468
#             1998    3.346
# ...

# %% [markdown]
# ## Understanding `value_counts()` with the `tips` dataset

# %%
tips = pd.read_csv('data/tips.csv')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size  fraction
# 0         16.99  1.01  Female     No   Sun  Dinner     2  0.059447
# 1         10.34  1.66    Male     No   Sun  Dinner     3  0.160542
# 2         21.01  3.50    Male     No   Sun  Dinner     3  0.166587
# 3         23.68  3.31    Male     No   Sun  Dinner     2  0.139780
# 4         24.59  3.61  Female     No   Sun  Dinner     4  0.146808
# ..          ...   ...     ...    ...   ...     ...   ...       ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3  0.203927
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2  0.073584
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2  0.088222
# 242       17.82  1.75    Male     No   Sat  Dinner     2  0.098204
# 243       18.78  3.00  Female     No  Thur  Dinner     2  0.159744
#
# [244 rows x 8 columns]

# %%
# How many males' do we have?

# What???
# len(tips[(tips.sex == 'Female') | (tips.sex == 'Male')])

tips.sex.value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
tips.groupby('sex').size()
# Out:
# sex
# Female     87
# Male      157
# dtype: int64

# %%
# How many smokers/non-smokers?
tips.smoker.value_counts().plot(kind='bar', xlabel='Smoker?')

# %%
smoker_counts = tips.smoker.value_counts()
smoker_counts
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
smoker_counts.index = ['Non-smoker', 'Smoker']
smoker_counts
# Out:
# Non-smoker    151
# Smoker         93
# Name: smoker, dtype: int64

# %%
# Numbers by sex and smoker status
tips.groupby(['sex', 'smoker']).size()
# Out:
# sex     smoker
# Female  No        54
#         Yes       33
# Male    No        97
#         Yes       60
# dtype: int64

# %%
g.groupby('region')['Country'].unique()
# Out:
# region
# America                       [Antigua and Barbuda, Argentina, Aruba, Bahama...
# East Asia & Pacific           [Australia, Brunei, Cambodia, China, Fiji, Fre...
# Europe & Central Asia         [Albania, Armenia, Austria, Azerbaijan, Belaru...
# Middle East & North Africa    [Algeria, Bahrain, Djibouti, Egypt, Iran, Iraq...
# South Asia                    [Afghanistan, Bangladesh, Bhutan, India, Maldi...
# Sub-Saharan Africa            [Angola, Benin, Botswana, Burkina Faso, Burund...
# Name: Country, dtype: object

# %%
g.fertility.apply
# Out:
# 0        7.671
# 1        7.671
# 2        7.671
# 3        7.671
# 4        7.671
#          ...
# 10106      NaN
# 10107      NaN
# 10108      NaN
# 10109      NaN
# 10110      NaN
# Name: fertility, Length: 10111, dtype: float64

# %%
g.groupby('region')['Country'].unique().apply(len)
# Out:
# region
# America                       40
# East Asia & Pacific           33
# Europe & Central Asia         52
# Middle East & North Africa    21
# South Asia                     8
# Sub-Saharan Africa            50
# Name: Country, dtype: int64

# %%
len(np.arange(10))
# Out:
# 10

# %%
tips.groupby(['sex', 'smoker'])['tip'].mean()
# Out:
# sex     smoker
# Female  No        2.773519
#         Yes       2.931515
# Male    No        3.113402
#         Yes       3.051167
# Name: tip, dtype: float64

# %%
tips.groupby(['sex', 'smoker'])['tip'].min()
# Out:
# sex     smoker
# Female  No        1.00
#         Yes       1.00
# Male    No        1.25
#         Yes       1.00
# Name: tip, dtype: float64

# %%
sgb = tips.groupby(['sex', 'smoker'])['tip']
sgb.max()
# Out:
# sex     smoker
# Female  No         5.2
#         Yes        6.5
# Male    No         9.0
#         Yes       10.0
# Name: tip, dtype: float64

# %%
aggregations = ['min', 'mean', 'max']
sgb.agg(aggregations)
# Out:
#                 min      mean   max
# sex    smoker
# Female No      1.00  2.773519   5.2
#        Yes     1.00  2.931515   6.5
# Male   No      1.25  3.113402   9.0
#        Yes     1.00  3.051167  10.0

# %%
np.arange(10).max()
# Out:
# 9

# %%
aggregation_params = {'total_bill': 'max', 'tip': 'mean'}
tips.groupby(['sex', 'smoker']).agg(aggregation_params)
# Out:
#                total_bill       tip
# sex    smoker
# Female No           35.83  2.773519
#        Yes          44.30  2.931515
# Male   No           48.33  3.113402
#        Yes          50.81  3.051167

# %%
aggregations = ['min', 'mean', 'max']
multiagg = tips.groupby(['sex', 'smoker']).agg(aggregations)
multiagg
# Out:
#               total_bill                     tip                 size  \
#                      min       mean    max   min      mean   max  min
# sex    smoker
# Female No           7.25  18.105185  35.83  1.00  2.773519   5.2    1
#        Yes          3.07  17.977879  44.30  1.00  2.931515   6.5    1
# Male   No           7.51  19.791237  48.33  1.25  3.113402   9.0    2
#        Yes          7.25  22.284500  50.81  1.00  3.051167  10.0    1
#
#                              fraction
#                    mean max       min      mean       max
# sex    smoker
# Female No      2.592593   6  0.056797  0.156921  0.252672
#        Yes     2.242424   4  0.056433  0.182150  0.416667
# Male   No      2.711340   6  0.071804  0.160669  0.291990
#        Yes     2.500000   5  0.035638  0.152771  0.710345

# %%
multiagg.index
# Out:
# MultiIndex([('Female',  'No'),
#             ('Female', 'Yes'),
#             (  'Male',  'No'),
#             (  'Male', 'Yes')],
#            names=['sex', 'smoker'])

# %%
multiagg.columns
# Out:
# MultiIndex([('total_bill',  'min'),
#             ('total_bill', 'mean'),
#             ('total_bill',  'max'),
#             (       'tip',  'min'),
#             (       'tip', 'mean'),
#             (       'tip',  'max'),
#             (      'size',  'min'),
#             (      'size', 'mean'),
#             (      'size',  'max'),
#             (  'fraction',  'min'),
#             (  'fraction', 'mean'),
#             (  'fraction',  'max')],
#            )

# %%
g.groupby()
